# %% [markdown]
# # INFO 2950 Final Project
# Alex Joos (aaj46), Jasmine Pearson (jcp348), Darby Bayne (dpb99)

# %% [markdown]
# ## **<div align="center">&#9658; Table of Contents &#9664;</div>**
#
#
# >1. [Introduction](#introduction)
# 2. [Data Descriptions](#datadescriptions)
# 3. [Data Cleaning](#datacleaning)
#     1. [Education](#education)
#     1. [Drug Use](#druguse)
#     1. [Internet Access](#internet)
#     1. [Religion](#religion)
#     1. [Political Spectrum](#political)
#     1. [Wealth](#wealth)
#     1. [UFO Sightings: Part One](#ufoone)
#     1. [UFO Sightings: Part Two](#ufotwo)
#     1. [Combining Dataframes](#combining)
# 5. [Running Regressions and Analysis](#anal)
#     1. [Cutting Down Data](#cutting)
#     1. [Linear Regressions](#linear)
#     1. [Logistic Regressions](#logistic)
# 6. [Conclusion](#conclusion)
#     1. [Preregistration Statement](#pre)
#     1. [Difficulties](#diff)
#     1. [Limitations](#limit)

# %% [markdown]
# ---

# %% [markdown]
# <a name="introduction"></a>
#
# ## **<div align="center">&#9658; Introduction &#9664;</div>**
#
# Our initial exploration into this study was confined to the surface level question of "what factors influence UFO sightings across various countries?" However, as we delve deeper into our research, we were drawn into a broader examinations of human behavior and psychology. Our journey evolved into an objective of understanding how factors such as access to technology, religious beliefs, and even hallucinogenic drug use can shape individual perceptions and influence the reporting of alien encounters.
#
# This study surpasses the realm of understanding how people view extraterrestrial phenomena and investigates the intricate strings that create unique behaviors within human culture. By analyzing background data, including religious statistics, democratic indices, and even hallucinogenic drug usage, we gain a glimpse into the diverse perspectives that define various societies. Our understanding of these cultural nuances extends beyond a casual investigation. It is a practical skill that fosters empathy and paves the way for deeper social connections across cultures. In essence, this study represents a journey of cultural exploration, a quest to bridge the gaps between human experiences. By comprehending the beliefs and perspectives of individuals from diverse backgrounds, we take a step closer towards fostering global unity and understanding.
#
# Something else we have learned is that the collection of data across all of these factors is not distributed equally. A lot of the data that we, Cornell University students, are exposed to had been biased towards United States data. Even though we prioritized including as much as we could from every available data sets that included other countries, we ultimately found that the only guaranteed data was provided for the United States. Being limited in such a way not only sets back our study, but potentially many other studies that are intended to study the psychological factors that may cause us to act and believe in ways that others do not. Work ethic, cultural traditions, cultural norms, and other ideas can never truly be accurately be studied to their fullest extent, and we take that into consideration when conducting our research. However, instead of being dissuaded, we dove headfirst into drawing possible correlations that will help us understand how and people from different countries think.

# %% [markdown]
# ----

# %% [markdown]
# <a name="datadescriptions"></a>
#
# ## **<div align="center">&#9658; Data Descriptions &#9664;</div>**
#
# We collected eleven data sets across our six factors, as well as one data set and one website of raw data for UFO sightings. While year is a factor in our analysis, we chose to group our data on year, and so it is not a factor we outline below because we collected no data sets on it specifically. We outline the data sets as follows:
#
# **Factor One: Drug Use**
#
# We scraped five data sets on drug use from the publically released National Survey on Drug Use and Health, one for each of the following years: 2021, 2019-2020, 2017-2018, 2015-2016, and 2013-2014. There was no published data for 2022. The information for data sets between 2017-2021 was only able to be downloaded in HTML or PDF format from the website. So, we downloaded the files locally as HTML and then re-saved them as HTML. Years 2013-2016 had to be manually inputted, as there was no format accessible (within the realm of this class) to scrape. The data sets contained information for ages 12+, and for each illicit drug type showed use for lifetime, past year, and past month.
#
# This data was created and released by SAMHSA (Substance Abuse and Mental Health Services Administration), an agency of the U.S. Department of Health and Human Services, to publicize trends and data on drug use in the United States. SAMHSA funds their research through Congress budgeting to promote mental health to provide support that fosterings equitable recovery.
#
# Since it is unclear specifically how SAMHSA gets their data, as online it says SAMHSA collects data through "multiple sources and surveys" but without comprehensive information on how these surveys are put out and who answers them, there could be various biases (such as response bias or sampling bias)that influence what data we see. The website also notes that respondents with missing data are generally excluded from the relevant analyses, which could also skew results.
#
# The data was preprocessed into tables that broke data down by age, race, year, and gender. Each table had an accompanying standard error table. The people who took these surveys were aware that they were submitting data and where said data was going. As noted above, respondents missing data were excluded from the final data sets.
#
# Source for 2013-2014: https://www.samhsa.gov/data/report/results-2014-national-survey-drug-use-and-h
#
# Source for 2015-2016: https://www.samhsa.gov/data/report/results-2016-national-survey-drug-use-and-health-detailed-tables
#
# Source for 2017-2018: https://www.samhsa.gov/data/report/2018-nsduh-detailed-tables
#
# Source for 2019-2020: https://www.samhsa.gov/data/report/2019-nsduh-detailed-tables
#
# Source for 2021: https://www.samhsa.gov/data/report/2021-nsduh-detailed-tables
#
#
# **Factor Two: Education**
#
# We used one data set to consider education. The data set measured how many years of schooling, on average, every country had from the year 1870 up until 2017. This data set had the following columns: country, alpha-3 country code, year, and average years of schooling.
#
# While we found this dataset on Kaggle, the publisher cited the following website as the original source: https://ourworldindata.org/global-education. However, this link did not work when we clicked on it. Googling the website instead tells us about their general data sourcing process, but does not specifically show the particular data we used. The data set was created to highlight global inequalities in education.
#
# The "Our World in Data" website acknowledges their data cleaning process as "standardizing country names and world region definitions, converting units, calculating derived indicators such as per capita measures, as well as adding or adapting metadata such as the name or the description given to an indicator", of course depending on the given data.
#
# Funding is from the non-profit organization Global Change Data Lab (GCDL), as well as from direct donations and grants. Researchers at the University of Oxford produce and maintain the data. The data is noted as being from four main sources: specialized institutes, research articles, international institutions or statistical agencies, and official data from government sources. Data from research articles could result in bias from personal opinion or in the skewed representation of data found.
#
# No specific people were subjects of this dataset.
#
#
# Source for years of schooling: https://www.kaggle.com/datasets/fredericksalazar/average-years-of-schooling-since-1870-2017
#
# **Factor Three: Democracy**
#
# When creating this data set, some resources that helped were
# Discussion 3, Discussion 8, and https://medium.com/@kudlamolka/
# scrap-data-from-wikipedia-table-to-csv-file-using-python-b5af7a6c858f.
#
#
# The data was listed by country label, essentially already as a presentable table. It contained attributes of:
# Region: What continent the country is in
# 2022 rank: The rank of the country in terms of its democracy index in 2022
# Country: The country that is being analyzed
# Regime Type: The type of regime in terms of Full democracies, Flawed democracies, Hybrid regimes, Authoritarian regimes, and No data (as stated above)
#
#
# For the observations,
# - 2022: Democracy Index measured in 2022
# - 2021: Democracy Index measured in 2021
# - 2020: Democracy Index measured in 2020
# - 2019: Democracy Index measured in 2019
# - 2018: Democracy Index measured in 2018
# - 2017: Democracy Index measured in 2017
# - 2016: Democracy Index measured in 2016
# - 2015: Democracy Index measured in 2015
# - 2014: Democracy Index measured in 2014
# - 2013: Democracy Index measured in 2013
# - 2012: Democracy Index measured in 2012
# - 2011: Democracy Index measured in 2011
# - 2010: Democracy Index measured in 2010
# - 2008: Democracy Index measured in 2008
# - 2006: Democracy Index measured in 2006
#
#
# The Wikimedia Foundation created this data set on their page "The Economist Democracy Index" on the website "Wikipedia The Free Encyclopedia"
#
# The purpose of this dataset was primarily to quantify and compare the democratic rights and institutions of large world nations. This was done according to the Economist Intelligence Unit, an Economist Group that is a UK-based private company that publishes the weekly paper in "The Economist".
#
#
# I believe that because the index was based mainly on categorizing measured ideas such as pluralism, civil liberties, and political cultures, some other possible factors or ways of measurement such as religion, the restrictiveness of laws, or how they view Western/traditional trends were not presented as potential predictors of the regime type.
#
# People were not directly involved in the study, as it was more of a general study of each country's culture.
#
# Source of Democracy Index: https://en.m.wikipedia.org/wiki/The_Economist_Democracy_Index
# I accessed this dataset using Beautiful Soup, as seen in the Appendix.
#
# **Factor Four: Wealth**
#
# We also scraped from a table of countries by total wealth, because the table "Shares of global wealth(%) of the ten wealthiest countries by net national wealth for 2000-2009, 2010-2019, 2020-2022" had the most continuous information starting from 2000 in comparison to the other tables presented. They also had the most interpretable data. The columns in the presented data table are:
#
# The columns go by:
# - Year: The year the global wealth % occurred
# - Australia: The total net national wealth of Australia during the year matching this row
# - Canada: The total net national wealth of Canada during the year matching this row
# - China: The total net national wealth of China during the year matching this row
# - France: The total net national wealth of France during the year matching this row
# - Germany: The total net national wealth of Germany during the year matching this row
# - India: The total net national wealth of India during the year matching this row
# - Italy: The total net national wealth of Italy during the year matching this row
# - Japan: The total net national wealth of Japan during the year matching this row
# - South Korea: The total net national wealth of  South Korea during the year matching this row
# - Spain: The total net national wealth of Spain during the year matching this row
# - United Kingdom: The total net national wealth of the UK during the year matching this row
# - United States: The total net national wealth of the US during the year matching this row
# - Aggregate share of the top 10: The total net national wealth of the top 10 during the year matching this row
#
# This is while the rows are by each specific year, specifically detailing the % of shares of global wealth.
#
# This data set was created to understand if this is a good indicator of a nation's ability to take on debt and sustain spending.
#
# The Wikimedia Foundation created this data set on their page "List of countries by total wealth" on the website "Wikipedia The Free Encyclopedia"
#
# Some processes that could have influenced what data was observed could have been the measurement of each specific asset and liability depending on the specific time it was measured. For example, exchange rates change by the minute, and because there is no exact time of day or time of year everything was observed, we only have a general idea of a country's national net worth. However, it is noted that real estate prices, equity market prices, exchange rates, liabilities, and incidence in a country the population can cause changes, but human resources, natural resources, and capital and technological advancements, can create new assets or render others worthless in the future. These are things that the initial source on Wikipedia takes into consideration.
#
# A specific group was not involved, as it was more of a general population study across countries.
#
# Source Total Wealth: https://en.wikipedia.org/wiki/List_of_countries_by_total_wealth
#
# I accessed this dataset using Beautiful Soup, as seen below.
#
# **Factor Five: Internet Access**
#
# This data is from the World Bank and spans the years 1989 (1960 until then are NaNs) to 2022, and gives data per year for each country of the percent of the country that has internet access. This data is being used as an indicator of access to technology.
#
# The attributes of the initial data set were sorted into columns based on:
# - Country
# - Most Recent Year
# - Most Recent Value
#
# The observations go by the specific country, year, and then the value from 0-100% for the percent of the population that has access to it.
#
# This data set was created because the internet has fundamentally changed how humanity learns, communicates, does business, and treats illnesses. Measuring access across the globe can help us understand how the internet can impact the development of the country as well as how the percentage of access it has can affect society.
#
#
# The World Bank uses trust funds, fundamentally from the International Bank for Reconstruction and Development (IBRD), and the International Development Association (IDA) to help fund their institutional goals
#
#
# Because the internet was counted through access to a computer, mobile phone, personal digital assistant, games machine, digital TV, etc., these traditional sources of telecommunication, some of the limitations considered were that these main measurements were only general measurements, not necessarily being precise. The quality of the collected data varied among reporting countries as a result of differences regarding regulations covering data provision and availability. Additionally, discrepancies arose from the differing end of fiscal years depending on countries.
#
#
# No, as it is a general population study.
#
# Source for global internet access data frame:
#
# link with dataset download: https://data.worldbank.org/indicator/IT.NET.USER.ZS?end=2022&most_recent_value_desc=true&start=1960
#
# Database origin: International Telecommunication Union ( ITU ) World Telecommunication/ICT Indicators Database
#
# **Factor Six: Religion**
#
# This data was sourced from Kaggle and contains data on the number of religious followers for different countries over time (1945-2010). The columns give each religion's followers for the country and date, as well as the percentages of each religion, and some stats for different combinations of religion types.
#
#
# The attributes of this data set before cleaning are: year
# - christianity_protestant
# - christianity_romancatholic
# - christianity_easternorthodox
# - christianity_anglican
# - christianity_other
# - christianity_all
# - judaism_orthodox
# - judaism_conservative
# - judaism_reform
# - judaism_other
# - judaism_all
# - islam_sunni
# - islam_shi’a
# - islam_ibadhi
# - islam_nationofislam
# - islam_alawite
# - islam_ahmadiyya
# - islam_other
# - islam_all
# - buddhism_mahayana
# - buddhism_theravada
# - buddhism_other
# - buddhism_all
# - zoroastrianism_all
# - hinduism_all
# - sikhism_all
# - shinto_all
# - baha’i_all
# - taoism_all
# - jainism_all
# - confucianism_all
# - syncretism_all
# - animism_all
# - noreligion_all
# - otherreligion_all
# - religion_all
# - population
# - world_population
# - protestant_percent
# - romancatholic_percent
# - easternorthodox_percent
# - anglican_percent
# - otherchristianity_percent
# - christianity_percent
# - orthodox_percent
# - conservative_percent
# - reform_percent
# - otherjudaism_percent
# - judaism_percent
# - sunni_percent
# - shi’a_percent
# - ibadhi_percent
# - nationofislam_percent
# - alawite_percent
# - ahmadiyya_percent
# - otherislam_percent
# - islam_percent
# - mahayana_percent
# - theravada_percent
# - otherbuddhism_percent
# - buddhism_percent
# - zoroastrianism_percent
# - hinduism_percent
# - sikhism_percent
# - shinto_percent
# - baha’i_percent
# - taoism_percent
# - jainism_percent
# - confucianism_percent
# - syncretism_percent
# - animism_percent
# - noreligion_percent
# - otherreligion_percent
# - religion_sumpercent
# - total_percent
#
# The observations were:
# The total observed population given the Country.
#
# The World Religion Project was created to provide detailed information about religious adherence worldwide since 1945. As described by the creators of the data: "It contains data about the number of adherents by religion in each of the states in the international system for every half-decade period. Some of the religions are divided into religious families, and the breakdown of adherents within a given religion into religious families is provided to the extent data are available." Overall, it is more of an observational creation rather than a study drawing a conclusion.
#
# The dataset was created by Zeev Maoz, University of California-Davis, and Errol Henderson, Pennsylvania State University, and published by the Correlates of War Project. However, UMichigan and Pennsylvania State University are the universities that funded the creation of this data set.
#
#
# Things such as data collection methods, as well as data availability, could have impacted the data that was observed. We do not know how the data was collected, and we also do not know if people answered with the religion that they truthfully believed. This can be due to the fear of disclosing their true religious affiliation in more conservative parts of the world with more firm consequences.
#
#
# It is unknown if people were directly involved, but we are observing it under the assumption that it is more of a consensus across countries.
#
# Source for Global Religions DataFrame 1945-2010: kaggle.com/datasets/umichigan/world-religions/?select=national.csv
#
# **UFO Sightings**
#
# We originally collected a data set from Kaggle containing over 80,000 UFO sightings. It measured datetime, city, state, country, shape, duration in seconds and hours, comments, date posted, latitude, and longitude.
#
# Source UFO sightings Kaggle: https://www.kaggle.com/datasets/NUFORC/ufo-sightings?select=scrubbed.csv
#
# However, upon closer inspection, we realized this data only had entries for five countries (United States, Germany, Australia, Great Britain, and Canada). So, we researched to find a more inclusive data set. We were unable to find such a dataset online, or even a table with more than just the data found in UFO Sightings Part One. So, instead, we noticed that the National UFO Reporting Center (NUFORC) had webpages for individual sightings with data (Occurred, Location, Shape, Duration, Reported, Posted) – we scraped from these pages for our final analysis.
#
# Example Source UFO sightings NUFORC: https://nuforc.org/sighting/?id=999
#
# The attributes are as follows:
# datetime
# city
# state
# country
# shape
# duration (seconds)
# duration (hours/min)
# comments
# date posted
# latitude
#
# The observations consist of:
# The specific data of a given alien sighting report.
#
# This data set was inspired by the following questions:
# "What areas of the country are most likely to have UFO sightings?
# Are there any trends in UFO sightings over time? Do they tend to be clustered or seasonal?
# Do clusters of UFO sightings correlate with landmarks, such as airports or government research centers?
# What are the most common UFO descriptions?"
#
# Generally, it seems inspired by a curiosity about UFO data, if there are any consistencies, and what appears to be the most common description.
#
# NUFORC is a non-governmental, non-profit corporation that takes donations and volunteer labor to keep it operating.
# The initial csv that we have only consisted of 5 countries, limiting our knowledge of what sightings could exist in other countries. Additionally, the funds put towards this research could have caused for less accessibility to other countries.
#
# People submit their reports through a button labeled "FILE A REPORT" on https://nuforc.org/, suggesting that without further inspection, they will not know. However, navigating the website to the data bank will make it clear that the report will be public. However, there is an Authorization that states "I hereby grant to The National UFO Reporting Center, its employees, agents, and personnel who are acting on its behalf (“NUFORC”), the absolute and irrevocable right and permission throughout the world and in perpetuity to use, re-use, publish, post on a website, transmit, modify, and edit the submitted report and any attached images, audio, video or other data or media (the Authorized Material). I hereby release and discharge NUFORC from all claims and demands arising out of any use of the Authorized Material or any reproduction thereof and waive any further claim for compensation in connection with the use of the Authorized Material." This suggests that the user has to willingly allow the website to publish/post the report.

# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd
import numpy as np
import time

import matplotlib.pyplot as plt
import seaborn as sns
import datetime

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.impute import SimpleImputer, SimpleImputer
from sklearn.compose import ColumnTransformer

import statsmodels.api as sm
import statsmodels.formula.api as smf

import duckdb

import plotly.express as px
import plotly.graph_objects as go

import re
from scipy.stats import pearsonr

# %% [markdown]
# -------------------------------

# %% [markdown]
# <a name="datacleaning"></a>
# <a name="education"></a>
#
# ## **<div align="center">&#9658; Data Cleaning: Education &#9664;</div>**
#
# We read in the file from the appenidix

# %%
education_df = pd.read_csv("education_df.csv")

education_df = education_df.drop(education_df.columns[0],
                              axis = 1)

education_df.head()
# Out:
#         Entity Code  Year  Average Years of Schooling
# 0  Afghanistan  AFG  1870                        0.01
# 1  Afghanistan  AFG  1875                        0.01
# 2  Afghanistan  AFG  1880                        0.01
# 3  Afghanistan  AFG  1885                        0.01
# 4  Afghanistan  AFG  1890                        0.01

# %% [markdown]
# We call head on the dataframe to visually confirm that the data was read in and deliminated correctly.

# %% [markdown]
# -------------------------------

# %% [markdown]
# <a name="internet"></a>
#
# ## **<div align="center">&#9658; Data Cleaning: Internet Access &#9664;</div>**
#
# We read in the file from the appenidix

# %%
internet_df = pd.read_csv("internet_df.csv")

internet_df = internet_df.drop(internet_df.columns[0],
                              axis = 1)

internet_df.head()
# Out:
#                   Country Name Country Code  year  internet access
# 0                        Aruba          ABW  1960              NaN
# 1  Africa Eastern and Southern          AFE  1960              NaN
# 2                  Afghanistan          AFG  1960              NaN
# 3   Africa Western and Central          AFW  1960              NaN
# 4                       Angola          AGO  1960              NaN

# %% [markdown]
# As done before, we continue to call head on the dataframe to visually make sure changes occurred as planned.

# %% [markdown]
# -------------------------------

# %% [markdown]
# <a name="religion"></a>
#
#
# ## **<div align="center">&#9658; Data Cleaning: Religion &#9664;</div>**

# %% [markdown]
# We read in the file from the appenidix

# %%
religion_df = pd.read_csv("religion_df.csv")

religion_df = religion_df.drop(religion_df.columns[0],
                              axis = 1)

religion_df.head()
# Out:
#    rounded year code              topReligion
# 0          1945  USA  christianity_protestant
# 1          1950  USA  christianity_protestant
# 2          1955  USA  christianity_protestant
# 3          1960  USA  christianity_protestant
# 4          1965  USA  christianity_protestant

# %% [markdown]
# We call head on the dataframe to confirm all our changes have been made as desired.

# %% [markdown]
# -------------------------------

# %% [markdown]
# <a name="political"></a>
#
#
# ## **<div align="center">&#9658; Data Cleaning: Political Spectrum &#9664;</div>**
#
#
# We read in the file from the appenidix

# %%
political_df = pd.read_csv("scrubbed_democracy_df.csv")

political_df = political_df.drop(political_df.columns[0],
                              axis = 1)

political_df.head()
# Out:
#          Country       Regime_Type  Year  Democracy_Index
# 0         Canada    Full democracy  2022             8.88
# 1  United States  Flawed democracy  2022             7.85
# 2        Austria    Full democracy  2022             8.20
# 3        Belgium  Flawed democracy  2022             7.64
# 4         Cyprus  Flawed democracy  2022             7.38

# %% [markdown]
# We call head on the dataframe to visually confirm that the data was read in and deliminated correctly.

# %% [markdown]
# -------------------------------

# %% [markdown]
# <a name="wealth"></a>
#
#
# ## **<div align="center">&#9658; Data Cleaning: Wealth &#9664;</div>**
#
#
# We read in the file from the appenidix

# %%
wealth_df = pd.read_csv("wealth_info.csv")

wealth_df = wealth_df.drop(wealth_df.columns[0],
                              axis = 1)

wealth_df.head()
# Out:
#    Year  Countries  Wealth_share_percent
# 0  2000  Australia                   NaN
# 1  2001  Australia                   NaN
# 2  2002  Australia                   NaN
# 3  2003  Australia                   1.9
# 4  2004  Australia                   1.9

# %% [markdown]
# We call head on the dataframe to confirm all our changes have been made as desired.

# %% [markdown]
# -------------------------------

# %% [markdown]
# <a name="ufoone"></a>
#
#
# ## **<div align="center">&#9658; Data Cleaning: UFO Sightings, Part One &#9664;</div>**
#
#
# We read in the file from the appenidix

# %%
scrubbed_location_df = pd.read_csv("scrubbed_location.csv")

scrubbed_location_df = scrubbed_location_df.drop(scrubbed_location_df.columns[0],
                                      axis = 1)

scrubbed_location_df.head()
# Out:
#            datetime country  year
# 0  10/10/1949 20:30      us  1949
# 1  10/10/1949 21:00     NaN  1949
# 2  10/10/1955 17:00      gb  1955
# 3  10/10/1956 21:00      us  1956
# 4  10/10/1960 20:00      us  1960

# %% [markdown]
# We call head on the dataframe to visually confirm that the data was read in and deliminated correctly.

# %% [markdown]
# ---

# %% [markdown]
# <a name="ufotwo"></a>
#
# ## **<div align="center">&#9658; Data Cleaning: UFO Sightings, Part Two &#9664;</div>**
#
# We read in the file from the appenidix

# %%
alien_df = pd.read_csv("alien_info.csv")

alien_df = alien_df.drop(alien_df.columns[0],
                                      axis = 1)

alien_df.head()
# Out:
#       Country Code  Year  Sightings
# 0              ARG  1959          0
# 1              AUS  1959          0
# 2              BRA  1959          0
# 3              CAN  1959          0
# 4  Channel Islands  1959          0

# %% [markdown]
# We call head to ensure everything looks okay visually

# %% [markdown]
# <a name="combining"></a>
#
# ## **<div align="center">&#9658; Data Cleaning: Combining the Dataframes &#9664;</div>**

# %% [markdown]
# We read in the file from the appenidix

# %%
everything_df = pd.read_csv("final_df.csv")

everything_df = everything_df.drop(['Unnamed: 0', 'Country Name_x', 'year_x', 'internet access_x'], 
                                      axis = 1)

everything_df.head()
# Out:
#       Country Code  Year  Sightings Entity  Average Years of Schooling  \
# 0              ARG  1959          0    NaN                         NaN
# 1              AUS  1959          0    NaN                         NaN
# 2              BRA  1959          0    NaN                         NaN
# 3              CAN  1959          0    NaN                         NaN
# 4  Channel Islands  1959          0    NaN                         NaN
#
#   Country Name_y  year_y  internet access_y  rounded year code  \
# 0            NaN     NaN                NaN           NaN  NaN
# 1            NaN     NaN                NaN           NaN  NaN
# 2            NaN     NaN                NaN           NaN  NaN
# 3            NaN     NaN                NaN           NaN  NaN
# 4            NaN     NaN                NaN           NaN  NaN
#
#    christianity_protestant  christianity_romancatholic  islam_other  \
# 0                        0                           0            0
# ...

# %% [markdown]
# <a name="pre"></a>
#
# ## Preregistration Statements:
#
# Null Hypothesis: Of the identified factors, none of the studied properties of location contribute
# significantly to the likelihood of an alien sighting.
#
#
# Preregistration One:
# - *Hypothesis 1*:
# Of the identified factors, the metric of access to technology is useful at determining the likelihood of an alien sighting.
# - *Analysis 1*:
# Run a linear regression where we input technology (as a numeric variable) and output the
# proportion of alien sightings (# of reported alien sightings / total sightings) reported in a
# country.
# Ex: For every 1% increase in access to technology, there will be an X% increase in the
# likelihood of an alien sighting.
#
#
# Preregistration Two:
# - *Hypothesis 2*:
# Of the identified factors, locations' religious differences determine the likelihood of an alien sighting.
# - *Analysis 2*:
# Run a linear regression where we input religion (as a dummy variable) and output the
# proportion of alien sightings (# of reported alien sightings / total sightings) reported in a
# country. The Christianity dummy will be our reference variable, so we will test whether
# BReligion > 0.

# %% [markdown]
# <a name="ex"></a>
#
# ## Exploratory And Visual Analysis:
#
# The following plots and other visualizations help us illustrate the distribution of values in the output and potential input columns over year and group by country. Additionally, it will help us discover what data is actually being included, helping us determine how we will run our statistical analysis of the data.
#
# We have decided to investigate the following traits of our data:
#
# - How the variables Year and Country compare differently when primarily investigating one of the variables
#
# -

# %%
# Plot line plots for each input/output column, over year group by state
def plot(col):
    ax = sns.lineplot(data=everything_df, x='Year', y=col, hue='Entity', marker='o')
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    ax.set_xlim(2005,2022)
    plt.show()

col_list = ['Sightings',"Average Years of Schooling","internet access_y","Democracy_Index","Wealth_share_percent","christianity_protestant","christianity_romancatholic"]
for c in col_list: plot(c)

# %% [markdown]
# The above graphs illustrate that the data heavily s

# %%
imputer = SimpleImputer(strategy='mean')
columns_to_impute = ['Year', 'Average Years of Schooling', 'internet access_y', 
                     'christianity_protestant', 'christianity_romancatholic', 
                     'Democracy_Index', 'Wealth_share_percent']
everything_df[columns_to_impute] = imputer.fit_transform(everything_df[columns_to_impute])

# %%
X = everything_df[['Year', 'Average Years of Schooling',
       'internet access_y', 'christianity_protestant',
       'christianity_romancatholic', 'Democracy_Index',
       'Wealth_share_percent']]
y = everything_df['Sightings']
model = LinearRegression()

# %%
plot_data = X.copy()
plot_data['Sightings'] = y

correlation_matrix = plot_data.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np

X_train, X_test, y_train, y_test = train_test_split(X, y,
                    test_size=0.2, random_state=2950)

model = LinearRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 0.65

# %%
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel('Actual')
plt.ylabel('Predicted')

plt.title(f'Actual vs Predicted\nRMSE: {rmse:.2f}')
plt.plot(np.unique(y_test), np.poly1d(np.polyfit(y_test, y_pred, 1))(np.unique(y_test)), color='red')

plt.show()

# %%
np.random.seed(2950)
mean_sightings = everything_df['Sightings'].mean()
std_sightings = everything_df['Sightings'].std()

normal_distribution = np.random.normal(mean_sightings, std_sightings, 10000)
plt.hist(normal_distribution, bins=100)
plt.xlabel('Sightings')
plt.ylabel('Frequency')
plt.title('Normal Distribution of Sightings')
plt.show()

# %%
# Split the dataset by 80% training and 20% testing
train, test= train_test_split(everything_df, test_size=0.2, random_state=2950)

# %% [markdown]
# **Heteroscedasticity:** We created residual plots for each predictor (x = predictor, y = Sightings) to check heteroscedasticity. For each plot, the more random that the residuals appear to be distributed, the more likely that there is no heteroscedasticity, thus, we can decipher that the more appropriate for us to include this variable as a predictor in our multilinear regression model.

# %%
var = train.columns

for v in var:
    try:
        sns.residplot(data=train, x=v, y='Sightings')
        plt.show()
    except TypeError as e:
        continue

# %%
var = train.columns[4:9]
for v in var:
    try:
        sns.lmplot(data=train, x=v, y='Sightings')
        plt.show()
    except ValueError as e:
        continue

# %% [markdown]
# **Hypothesis Testing:**

# %%
def summary(everything_df, input):
    X = everything_df[input]
    X = X.replace([np.inf, -np.inf], np.nan)
    X = X.dropna()
    reg = sm.OLS(everything_df['Sightings'], X).fit()
    print(reg.summary())

for x in range(len(everything_df.columns)):
    try:
        summary(train, everything_df.columns[x])
    except (ValueError or MissingDataError) as e:
        continue
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:              Sightings   R-squared (uncentered):                   0.061
# Model:                            OLS   Adj. R-squared (uncentered):              0.059
# Method:                 Least Squares   F-statistic:                              23.07
# Date:                Tue, 05 Dec 2023   Prob (F-statistic):                    2.31e-06
# Time:                        11:51:58   Log-Likelihood:                         -619.26
# No. Observations:                 355   AIC:                                      1241.
# Df Residuals:                     354   BIC:                                      1244.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Analysis / Conclusion of Significance: Internet Access**
# The results of the t-test shows that the p-value for internet access is roughly 0.657, which is much larger than the 0.05 cut off point we have chosen. This means that we can fail to reject the null hypothesis, and conclude that the level of internet access does *not* affect the number of alien sighting reports.
#
# The same can be said about religion as being a Christian - Protestant or Christian - Roman Catholic both generate p-values above 0.05, (0.074 and 0.942),
#
# However, an interesting finding is that Average Years of Schooling, Democracy_Index, and Wealth_share_percent all share p-values below 0.05. In more detail:
#
# - The results of the t-test shows that the p-value for Average Years of Schooling is roughly 0.026, which is smaller than the significance value of 0.05, meaning that we can reject the null hypothesis, and conclude that the Average Years of Schooling does affect the reported amount of alien sightings. Something to take note of is that it holds a positive coefficient of 0.0833 when we make our for-loop only go through 115 observations, meaning that for each additional year of schooling, the amount of sightings reported increases by 0.0833.

# %% [markdown]
# <a name="conclusion"></a>
#
# ## Conclusion:
#
# Our project explored the geographical and cultural factors that we assumed would best predict the number of reported alien sightings given a specific location and year. Our dataset included 266 rows and 73 columns. Each row represented a country per year (e.g. United States in the Year 2020). The first two columns were Country Name and Country Code, while the next were years spanning from 1960 to 2022. The rest were topReligion, Regime_Type, Democracy_Index, Wealth_share_percent, Year, Country, and num_sightings.
#
# Even though our null hypothesis were failed to be rejected, it was very interesting to find out that the average amount of years being in school, level of democracy within a country, and how wealthy a nation is can affect the amount of alien sightings that are reported. However, the coefficients all tell different stories as the school and wealth coefficients are positive while the democracy coefficient is negative. Again, this could be because this test is currently being run with a smaller sample as the for loop that includes the additonal numbers can only run so much RAM on an Apple product using Cornell's wifi.

# %% [markdown]
# <a name="diff"></a>
#
# ## Difficulties faced during data collection:
#
# Our biggest issue during data collection was finding data within the same range of years. Some of our data went all the way back to the 1600's, while other viable data only could be found within, for example, years 2013-2021. So, this made it hard to analyse the data meaningfully.
#
# Another issue was in unsimilar data types and unfamiliar file formats. For example, in our religion data set, the counts of different religions first seemed like they were all integers, but upon inspection a few of them were floats. While this wasn't hard to fix, it did take time to figure out which data entries needed fixing. We also ran into an issue with the HTM file. Upon trying to download it, it removed itself from the computer and didn't appear. Once we restarted the computer and downloaded the file to the desktop instead of into a folder, we were able to correctly save and convert it to HTML.

# %% [markdown]
# <a name="limit"></a>
#
# ## Limitations:
#
# We ran into limitations in range of years, as mentioned in difficulties faced, where every data set we included had vastly different ranges of years. Cutting the data into a shared specific set of years would make it much smaller and result in less accurate predictions, but keeping to too large would make it hard to manage. We also had a lot of NaN values since we were dealing with such diverse and widespread data, which made seeing clear analyses more difficult.
#
# Most of the data for UFO sightings are reported from the United States. This could result in potentional bias in our analysis, as a disproportionate focus on U.S.-centric data might inadvertently skew our findings and influence the way readers interpret the results.

# %% [markdown]
# ---

# %% [markdown]
# ## Other Sources
#
# 1. Used for formatting of Markdown outside of what was covered in class: https://www.ibm.com/docs/en/db2-event-store/2.0.0?topic=notebooks-markdown-jupyter-cheatsheet
# 1. Used while creating top_df to solve a SettingWithCopyError: https://github.com/pandas-dev/pandas/issues/39418
# 1. Used to get country codes and corresponding countruy names: https://www.iban.com/country-codes
